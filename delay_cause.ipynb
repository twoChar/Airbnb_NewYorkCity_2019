# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ds = pd.read_csv('Airline_Delay_Cause.csv')
ds.head()
# Out:
#    year  month carrier       carrier_name airport  \
# 0  2023      8      9E  Endeavor Air Inc.     ABE
# 1  2023      8      9E  Endeavor Air Inc.     ABY
# 2  2023      8      9E  Endeavor Air Inc.     AEX
# 3  2023      8      9E  Endeavor Air Inc.     AGS
# 4  2023      8      9E  Endeavor Air Inc.     ALB
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...         89.0       13.0
# 1             Albany, GA: Southwest Georgia Regional         62.0       10.0
# 2           Alexandria, LA: Alexandria International         62.0       10.0
# 3        Augusta, GA: Augusta Regional at Bush Field         66.0       12.0
# 4                   Albany, NY: Albany International         92.0       22.0
#
#    carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# 0        2.25        1.60  ...          0.0              5.99            2.0
# ...

# %%
ds.shape
# Out:
# (100000, 21)

# %%
display(ds.describe().T)
# Out:
#                         count         mean           std     min      25%  \
# year                 100000.0  2020.617710      1.501914  2018.0  2019.00
# month                100000.0     6.531960      3.455178     1.0     4.00
# arr_flights           99840.0   320.833433    908.228876     1.0    39.00
# arr_del15             99652.0    57.294274    165.204000     0.0     5.00
# carrier_ct            99840.0    19.340233     50.635184     0.0     1.93
# weather_ct            99840.0     2.127702      7.379922     0.0     0.00
# nas_ct                99840.0    15.906943     54.360829     0.0     0.71
# security_ct           99840.0     0.171568      0.810006     0.0     0.00
# late_aircraft_ct      99840.0    19.639993     64.653064     0.0     0.99
# arr_cancelled         99840.0     8.074379     51.573767     0.0     0.00
# arr_diverted          99840.0     0.753265      3.398723     0.0     0.00
# arr_delay             99840.0  3852.557192  12349.349881     0.0   263.00
# ...

# %%
ds.isnull().sum()

# %%
ds.dtypes

# %%
# Distribution of Numeric Features
numeric_features = ['arr_flights', 'arr_del15', 'carrier_ct', 'weather_ct', 'nas_ct',
                    'security_ct', 'late_aircraft_ct', 'arr_cancelled', 'arr_diverted',
                    'arr_delay', 'carrier_delay', 'weather_delay', 'nas_delay',
                    'security_delay', 'late_aircraft_delay']

for i in numeric_features:
    plt.figure(figsize=(10, 6))
    sns.histplot(ds[i], kde=True, color='blue', bins =50)
    plt.title(i)
    plt.show()

# %%
#number of unique values in each column
ds.nunique()
# ds["carrier"].nunique()
# Out:
# year                       6
# month                     12
# carrier                   18
# carrier_name              19
# airport                  381
# airport_name             405
# arr_flights             4307
# arr_del15               1425
# carrier_ct             10926
# weather_ct              3026
# nas_ct                 10004
# security_ct              792
# late_aircraft_ct       11072
# arr_cancelled            526
# arr_diverted              97
# arr_delay              15290
# carrier_delay           9333
# weather_delay           3494
# nas_delay               6910
# security_delay           531
# late_aircraft_delay     9649
# dtype: int64

# %%
category_features = ['carrier', 'carrier_name','airport', 'airport_name']
for i in category_features:
